# %%
# !nnUNetv2_train 001 3d_fullres 0 -device cuda --npz
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2024-09-25 23:18:40.623755: do_dummy_2d_data_aug: False
# 2024-09-25 23:18:40.637353: Using splits from existing split file: C:\Users\Leo\Documents\UHN-MedImg3D-ML-quiz\nnUNet_preprocessed\Dataset001_Pancreas\splits_final.json
# ...

# %%
# !nnUNetv2_train 001 3d_fullres 1 -device cuda --npz
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2024-09-26 08:23:59.050952: do_dummy_2d_data_aug: False
# 2024-09-26 08:23:59.060282: Using splits from existing split file: C:\Users\Leo\Documents\UHN-MedImg3D-ML-quiz\nnUNet_preprocessed\Dataset001_Pancreas\splits_final.json
# ...

# %%
# !nnUNetv2_train 001 3d_fullres 2 -device cuda --npz
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2024-09-26 17:33:14.357785: do_dummy_2d_data_aug: False
# 2024-09-26 17:33:14.367000: Using splits from existing split file: C:\Users\Leo\Documents\UHN-MedImg3D-ML-quiz\nnUNet_preprocessed\Dataset001_Pancreas\splits_final.json
# ...

# %%
# !nnUNetv2_train 001 3d_fullres 3 -device cuda --npz
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2024-09-27 02:39:41.983906: do_dummy_2d_data_aug: False
# 2024-09-27 02:39:41.989911: Using splits from existing split file: C:\Users\Leo\Documents\UHN-MedImg3D-ML-quiz\nnUNet_preprocessed\Dataset001_Pancreas\splits_final.json
# ...

# %%
# !nnUNetv2_train 001 3d_fullres 4 -device cuda --npz
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2024-09-27 11:48:07.391517: do_dummy_2d_data_aug: False
# 2024-09-27 11:48:07.404190: Using splits from existing split file: C:\Users\Leo\Documents\UHN-MedImg3D-ML-quiz\nnUNet_preprocessed\Dataset001_Pancreas\splits_final.json
# ...

# %%
# !nnUNetv2_train 001 2d 1 -device cuda --npz
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2024-09-27 20:53:24.603264: do_dummy_2d_data_aug: False
# 2024-09-27 20:53:24.627451: Using splits from existing split file: C:\Users\Leo\Documents\UHN-MedImg3D-ML-quiz\nnUNet_preprocessed\Dataset001_Pancreas\splits_final.json
# ...

# %%
# !nnUNetv2_train 001 2d 2 -device cuda --npz
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2024-09-28 02:53:45.797913: do_dummy_2d_data_aug: False
# 2024-09-28 02:53:45.806430: Using splits from existing split file: C:\Users\Leo\Documents\UHN-MedImg3D-ML-quiz\nnUNet_preprocessed\Dataset001_Pancreas\splits_final.json
# ...

# %%
# !nnUNetv2_train 001 2d 3 -device cuda --npz
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2024-09-28 08:54:33.714832: do_dummy_2d_data_aug: False
# 2024-09-28 08:54:33.722962: Using splits from existing split file: C:\Users\Leo\Documents\UHN-MedImg3D-ML-quiz\nnUNet_preprocessed\Dataset001_Pancreas\splits_final.json
# ...

# %%
# !nnUNetv2_train 001 2d 4 -device cuda --npz
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2024-09-28 14:58:26.189435: do_dummy_2d_data_aug: False
# 2024-09-28 14:58:26.199538: Using splits from existing split file: C:\Users\Leo\Documents\UHN-MedImg3D-ML-quiz\nnUNet_preprocessed\Dataset001_Pancreas\splits_final.json
# ...
